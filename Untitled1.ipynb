# %%
import nltk

# %%
article = open("C:/Users/balaj/Downloads/NLP/articles.txt",'r',errors='ignore')
print(article.read())
# Out:
# ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business
#
#
# Ride-sharing firm Uber is facing a criminal investigation by the US government.
#
#
# The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.
#
#
# The software, called "greyball", helped it identify officials seeking to stop the service running.
#
#
# A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.
#
#
# It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.
#
#
# Bookings blocked
#
#
# In those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally. Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.
#
#
# ...

# %%
sentences = nltk.sent_tokenize(str(article))

# %%
print(sentences)
# Out:
# ["<_io.TextIOWrapper name='C:/Users/balaj/Downloads/NLP/articles.txt' mode='r' encoding='cp1252'>"]

# %%
myp = open("C:/Users/balaj/OneDrive/Desktop/New Text Document.txt",'r')
print(myp.read())
# Out:
# Weak AI(ANI)
# General AI(AGI)
# Super AI(ASI)

# %%
article
# Out:
# <_io.TextIOWrapper name='C:/Users/balaj/Downloads/NLP/articles.txt' mode='r' encoding='cp1252'>

# %%
art = str(article)

# %%
art
# Out:
# "<_io.TextIOWrapper name='C:/Users/balaj/Downloads/NLP/articles.txt' mode='r' encoding='cp1252'>"

# %%
print(article.read())

# %%
sents = []
with open('articles.txt','r',errors ='ignore') as f:
    sents = nltk.sent_tokenize(str(f))

# %%
sents
# Out:
# ["<_io.TextIOWrapper name='articles.txt' mode='r' encoding='cp1252'>"]

# %%
print(sents.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a6273cd79e60> in <module>
# ----> 1 print(sents.read())
#
# AttributeError: 'list' object has no attribute 'read'

# %%
with open('articles.txt','r',errors ='ignore') as m:
    senten = nltk.sent_tokenize(str(m))
    words = nltk.word_tokenize(str(senten))
    print(words)
# Out:
# ['[', '``', '<', '_io.TextIOWrapper', "name='articles.txt", "'", 'mode=', "'", 'r', "'", "encoding='cp1252", "'", '>', "''", ']']

# %%
file1 = 'articles.txt'
file2 = open(file1, 'r', errors = 'ignore')
article = file2.read()
file2.close()

# %%
type(article)
# Out:
# str

# %%
article
# Out:
# 'ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business\n\n\nRide-sharing firm Uber is facing a criminal investigation by the US government.\n\n\nThe scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.\n\n\nThe software, called "greyball", helped it identify officials seeking to stop the service running.\n\n\nA spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.\n\n\nIt is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.\n\n\nBookings blocked\n\n\nIn those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally. Greyball worked out who the officials were and blocked them from booking rides with the company\'s drivers.\n\n\nIn a letter sent last week 
# ...

# %%
sentences = nltk.sent_tokenize(article,language='english')

# %%
sentences
# Out:
# ['ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business\n\n\nRide-sharing firm Uber is facing a criminal investigation by the US government.',
#  'The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.',
#  'The software, called "greyball", helped it identify officials seeking to stop the service running.',
#  'A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.',
#  'It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.',
#  'Bookings blocked\n\n\nIn those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally.',
#  "Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.",
# ...

# %%
words = [nltk.word_tokenize(sent) for sent in sentences]

# %%
words
# Out:
# [['ï',
#   '»',
#   '¿Image',
#   'copyright',
#   'EPA',
#   'Image',
#   'caption',
#   'Uber',
#   'has',
#   'been',
#   'criticised',
#   'many',
#   'times',
#   'over',
#   'the',
#   'way',
#   'it',
#   'runs',
#   'its',
#   'business',
#   'Ride-sharing',
#   'firm',
#   'Uber',
#   'is',
#   'facing',
#   'a',
#   'criminal',
#   'investigation',
#   'by',
#   'the',
#   'US',
#   'government',
#   '.'],
#  ['The',
#   'scrutiny',
#   'has',
#   'started',
#   'because',
#   'the',
#   'firm',
#   'is',
#   'accused',
#   'of',
#   'using',
#   '``',
#   'secret',
#   "''",
#   'software',
#   'that',
#   'let',
#   'it',
#   'operate',
#   'in',
#   'regions',
#   'where',
#   'it',
#   'was',
#   'banned',
#   'or',
#   'restricted',
#   '.'],
#  ['The',
#   'software',
#   ',',
#   'called',
#   '``',
#   'greyball',
#   "''",
#   ',',
#   'helped',
#   'it',
#   'identify',
#   'officials',
#   'seeking',
#   'to',
#   'stop',
#   'the',
#   'service',
#   'running',
# ...

# %%
pos_sentences = [nltk.pos_tag(sent) for sent in sentences]

# %%
sentences
# Out:
# ['ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business\n\n\nRide-sharing firm Uber is facing a criminal investigation by the US government.',
#  'The scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.',
#  'The software, called "greyball", helped it identify officials seeking to stop the service running.',
#  'A spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.',
#  'It is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.',
#  'Bookings blocked\n\n\nIn those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally.',
#  "Greyball worked out who the officials were and blocked them from booking rides with the company's drivers.",
# ...

# %%
sentences[0]
# Out:
# 'ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business\n\n\nRide-sharing firm Uber is facing a criminal investigation by the US government.'

# %%
nltk.word_tokenize(sentences[0])
# Out:
# ['ï',
#  '»',
#  '¿Image',
#  'copyright',
#  'EPA',
#  'Image',
#  'caption',
#  'Uber',
#  'has',
#  'been',
#  'criticised',
#  'many',
#  'times',
#  'over',
#  'the',
#  'way',
#  'it',
#  'runs',
#  'its',
#  'business',
#  'Ride-sharing',
#  'firm',
#  'Uber',
#  'is',
#  'facing',
#  'a',
#  'criminal',
#  'investigation',
#  'by',
#  'the',
#  'US',
#  'government',
#  '.']

# %%
word1 = nltk.word_tokenize(sentences[0])

# %%
nltk.pos_tag(word1)
# Out:
# [('ï', 'JJ'),
#  ('»', 'NNP'),
#  ('¿Image', 'NN'),
#  ('copyright', 'NN'),
#  ('EPA', 'NNP'),
#  ('Image', 'NNP'),
#  ('caption', 'NN'),
#  ('Uber', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('criticised', 'VBN'),
#  ('many', 'JJ'),
#  ('times', 'NNS'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('it', 'PRP'),
#  ('runs', 'VBZ'),
#  ('its', 'PRP$'),
#  ('business', 'NN'),
#  ('Ride-sharing', 'JJ'),
#  ('firm', 'NN'),
#  ('Uber', 'NNP'),
#  ('is', 'VBZ'),
#  ('facing', 'VBG'),
#  ('a', 'DT'),
#  ('criminal', 'JJ'),
#  ('investigation', 'NN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('US', 'JJ'),
#  ('government', 'NN'),
#  ('.', '.')]

# %%
words
# Out:
# [['ï',
#   '»',
#   '¿Image',
#   'copyright',
#   'EPA',
#   'Image',
#   'caption',
#   'Uber',
#   'has',
#   'been',
#   'criticised',
#   'many',
#   'times',
#   'over',
#   'the',
#   'way',
#   'it',
#   'runs',
#   'its',
#   'business',
#   'Ride-sharing',
#   'firm',
#   'Uber',
#   'is',
#   'facing',
#   'a',
#   'criminal',
#   'investigation',
#   'by',
#   'the',
#   'US',
#   'government',
#   '.'],
#  ['The',
#   'scrutiny',
#   'has',
#   'started',
#   'because',
#   'the',
#   'firm',
#   'is',
#   'accused',
#   'of',
#   'using',
#   '``',
#   'secret',
#   "''",
#   'software',
#   'that',
#   'let',
#   'it',
#   'operate',
#   'in',
#   'regions',
#   'where',
#   'it',
#   'was',
#   'banned',
#   'or',
#   'restricted',
#   '.'],
#  ['The',
#   'software',
#   ',',
#   'called',
#   '``',
#   'greyball',
#   "''",
#   ',',
#   'helped',
#   'it',
#   'identify',
#   'officials',
#   'seeking',
#   'to',
#   'stop',
#   'the',
#   'service',
#   'running',
# ...

# %%
pos_w = [nltk.pos_tag(word) for word in words]

# %%
pos_w
# Out:
# [[('ï', 'JJ'),
#   ('»', 'NNP'),
#   ('¿Image', 'NN'),
#   ('copyright', 'NN'),
#   ('EPA', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('Uber', 'NNP'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('criticised', 'VBN'),
#   ('many', 'JJ'),
#   ('times', 'NNS'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('way', 'NN'),
#   ('it', 'PRP'),
#   ('runs', 'VBZ'),
#   ('its', 'PRP$'),
#   ('business', 'NN'),
#   ('Ride-sharing', 'JJ'),
#   ('firm', 'NN'),
#   ('Uber', 'NNP'),
#   ('is', 'VBZ'),
#   ('facing', 'VBG'),
#   ('a', 'DT'),
#   ('criminal', 'JJ'),
#   ('investigation', 'NN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('US', 'JJ'),
#   ('government', 'NN'),
#   ('.', '.')],
#  [('The', 'DT'),
#   ('scrutiny', 'NN'),
#   ('has', 'VBZ'),
#   ('started', 'VBN'),
#   ('because', 'IN'),
#   ('the', 'DT'),
#   ('firm', 'NN'),
#   ('is', 'VBZ'),
#   ('accused', 'VBN'),
#   ('of', 'IN'),
#   ('using', 'VBG'),
#   ('``', '``'),
#   ('secret', 'JJ'),
#   ("''", "''"),
# ...

# %%
chunked_sentences = nltk.ne_chunk_sents(pos_w,binary=True)

# %%
chunked_sentences
# Out:
# <generator object ParserI.parse_sents.<locals>.<genexpr> at 0x000002B777F19BA0>

# %%
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, "label") and chunk.label() == "NE":
            print(chunk)
# Out:
# (NE EPA/NNP Image/NNP)
# (NE US/JJ)
# (NE Reuters/NNPS)
# (NE Portland/NNP)
# (NE Oregon/NNP)
# (NE Greyball/NNP)
# (NE Portland/NNP)
# (NE Uber/NNP)
# (NE Uber/NNP)
# (NE New/NNP York/NNP Times/NNP)
# (NE Uber/NNP)
# (NE Alexa/NNP)
# (NE Siri/NNP)
# (NE Rachael/NNP Tatman/NNP)
# (NE South/NNP)
# (NE New/NNP Zealand/NNP)
# (NE Tatman/NNP)
# (NE San/NNP Francisco/NNP)
# (NE Tatman/NNP)
# (NE University/NNP)
# (NE Virtual/NNP Assistant/NNP Summit/NNP)
# (NE Park/NNP Central/NNP Hotel/NNP)
# (NE Tatman/NNP)
# (NE Tatman/NNP)
# (NE Southern/JJ)
# (NE California/NNP)
# (NE South/NNP)
# (NE United/NNP States/NNPS)
# (NE Southern/NNP)
# (NE Stephen/NNP Scarr/NNP)
# (NE CEO/NNP)
# (NE eContext/NN)
# (NE YouTube/NNP)
# (NE Alonso/NNP Martinez/NNP)
# (NE Pixar/NNP Animation/NNP Studios/NNP)
# (NE Martinez/NNP)
# (NE Emeryville/NNP)
# (NE Elena/NNP Corina/NNP Grigore/NNP)
# (NE Yale/NNP)
# (NE Grigore/NNP)
# (NE Ikea/NNP)
# (NE Grigore/NNP)
# (NE Benny/NNP Evangelista/NNP)
# ...

# %%
import pandas as pd
from collections import defaultdict

# %%
# Create the defaultdict: ner_categories
ner_categories = defaultdict(int)

# %%
import matplotlib.pyplot as plt

# %%
# Create the nested for loop
for sent in chunked_sentences:
    for chunk in sent:
        if hasattr(chunk, 'label'):
            ner_categories[chunk.label()] += 1
            # Create a list from the dictionary keys for the chart labels: labels
            labels = list(ner_categories.keys())
            # Create a list of the values: values
            values = [ner_categories.get(v) for v in labels]

# %%
ner_categories
# Out:
# defaultdict(int, {})

# %%
# Create the pie chart
plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=140)

# Display the chart
plt.show()

# %%
article
# Out:
# 'ï»¿Image copyright EPA Image caption Uber has been criticised many times over the way it runs its business\n\n\nRide-sharing firm Uber is facing a criminal investigation by the US government.\n\n\nThe scrutiny has started because the firm is accused of using "secret" software that let it operate in regions where it was banned or restricted.\n\n\nThe software, called "greyball", helped it identify officials seeking to stop the service running.\n\n\nA spokesman for Uber declined to comment on the investigation, reported the Reuters news agency.\n\n\nIt is claimed greyball was used in several areas, including Portland, Oregon, where the ride service was still seeking official approval to operate.\n\n\nBookings blocked\n\n\nIn those areas, transport regulation officials posed as passengers in a bid to prove that the company was operating illegally. Greyball worked out who the officials were and blocked them from booking rides with the company\'s drivers.\n\n\nIn a letter sent last week 
# ...

# %%
labels
# Out:
# []

# %%
values
# Out:
# []

# %%
chunked_sentences
# Out:
# <generator object ParserI.parse_sents.<locals>.<genexpr> at 0x000002B777F19BA0>

# %%
pip install spacy

# %%
import spacy

# %%
# Instantiate the English model: nlp
nlp = spacy.load(tagger=False,parser=False,matcher=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-dc479810998b> in <module>
#       1 # Instantiate the English model: nlp
# ----> 2 nlp = spacy.load(tagger=False,parser=False,matcher=False)
#
# TypeError: load() missing 1 required positional argument: 'name'
